# %%
import math
def factorial(x:int):
    fact = 1
    for i in range(1, x+1):
        fact *= i
    return fact

def cosaprox(x:int, n:int):
    cosap = 0
    for i in range(0, n+1):
        cosap += (-1)**i * ((x)**(2*i))/factorial(2*i)
    return cosap

def cosreal(x:int):
    cosre = math.cos(x)
    return cosre

def calcularn(x:int):
    n = 0
    aprox  = cosaprox(x,n)
    real = cosreal(x)
    error = abs(real - aprox)
    while error > 0.00001:
        n += 1
        aprox = cosaprox(x,n)
        real = cosreal(x)
        error = abs(real - aprox)
    return n

def calcularn2(x:int):
    n = 0
    aprox  = cosaprox(x,n)
    real = cosreal(x)
    error = abs(real - aprox)
    while error > 0.001:
        n += 1
        aprox = cosaprox(x,n)
        real = cosreal(x)
        error = abs(real - aprox)
    return n

def calcularn3(x:int):
    n = 0
    aprox  = cosaprox(x,n)
    real = cosreal(x)
    error = abs(real - aprox)
    while error > 0.01:
        n += 1
        aprox = cosaprox(x,n)
        real = cosreal(x)
        error = abs(real - aprox)
    return n

def calcularn4(x:int):
    n = 0
    aprox  = cosaprox(x,n)
    real = cosreal(x)
    error = abs(real - aprox)
    while error > 0.1:
        n += 1
        aprox = cosaprox(x,n)
        real = cosreal(x)
        error = abs(real - aprox)
    return n

if __name__ == "__main__":
    x = float(input("ingrese un numero x"))
    n = int(input("Ingrese la cantidad de sumatorias de taylord a evaluar"))
    aprox = cosaprox(x,n)
    real = cosreal(x)
    nerror = calcularn(x)
    nerror2 = calcularn2(x)
    nerror3 = calcularn3(x)
    nerror4 = calcularn4(x)
    error = abs(real - aprox)
    print("el valor arpoximado del coseno de " + str(x) + " es: " + str(aprox) + " y El valor real es: " + str(real))
    print("El error con " +str(n)+" sumas es: " + str(error)) 
    print("Para un error menor al 10% la cantidad de 'n' que se necesitan son: " + str(nerror4))  
    print("Para un error menor al 1% la cantidad de 'n' que se necesitan son: " + str(nerror3))
    print("Para un error menor al 0.1% la cantidad de 'n' que se necesitan son: " + str(nerror2))  
    print("Para un error menor al 0.001% la cantidad de 'n' que se necesitan son: " + str(nerror))
# Out:
# el valor arpoximado del coseno de 4.0 es: -0.6536440575891425 y El valor real es: -0.6536436208636119
# El error con 9 sumas es: 4.367255305171014e-07
# Para un error menor al 10% la cantidad de 'n' que se necesitan son: 5
# Para un error menor al 1% la cantidad de 'n' que se necesitan son: 6
# Para un error menor al 0.1% la cantidad de 'n' que se necesitan son: 7
# Para un error menor al 0.001% la cantidad de 'n' que se necesitan son: 9
